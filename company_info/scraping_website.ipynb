# %%
import re
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Launch Chrome
print('Starting Webdriver...')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.emploidakar.com/les-10-meilleures-entreprises-btp-au-senegal/")

html = driver.page_source
soup = BeautifulSoup(html, "lxml")

print('Scraping Company Info...')
article = soup.find("div", class_="entry-content single-page")
companies = []

for blocks in article.find_all("h3"):
    company_name = blocks.get_text(strip=True).split('.')[1].strip()
    p_blocks = [p.get_text(strip=True) for p in blocks.find_next_siblings("p", limit=3)]

    info_block = p_blocks[0] if len(p_blocks) > 0 else "BTP"
    address_block = p_blocks[1] if len(p_blocks) > 1 else ""
    contact_block = p_blocks[2] if len(p_blocks) > 2 else ""

    email_match = re.search(r"[\w.-]+@[\w.-]+\.\w+", contact_block)
    email = email_match.group(0) if email_match else ""

    phone_match = re.findall(r"\+?\d[\d\s\-]+", contact_block)
    phones = phone_match if phone_match else []

    addr_match = re.search(r"Adresse\s*:?\s*(.+)", address_block)
    address = addr_match.group(1).strip() if addr_match else address_block

    companies.append({
        "name": company_name,
        "info": info_block,
        "address": address,
        "email": email,
        "phones": phones
    })

driver.quit()
# Out:
# Starting Webdriver...
# Scraping Company Info...

# %%
def comp_type(name):
    info = name.get('info', '').lower()
    if 'mines' in info or 'minier' in info:
        name['info'] = 'BTP/MINIER'
    elif 'ong' in info:
        name['info'] = 'ONG'
    elif 'btp' in info or 'btp' not in info:
        name['info'] = 'BTP'
    else:
        name['info'] = 'OTHERS'

# %%
for company in companies:
    company['pays'] = 'SENEGAL'
    comp_type(company)

    # Clean up phones: always join if it's a list
    if isinstance(company['phones'], list):
        company['phones'] = "/ ".join(company['phones'])
        company['phones'] = company['phones'].strip()
    else:
        company['phones'] = str(company['phones']) if company['phones'] else ""

    # Clean up address: if it's a list, take the first element
    if isinstance(company['address'], list):
        company['address'] = company['address'][0]

print('Storing Company Info...')
# Out:
# Storing Company Info...

# %%
df = pd.DataFrame(companies)
df.drop_duplicates(inplace=True)
df
# Out:
#                                name        info  \
# 0  Groupe Soeco-Poncet et Compagnie         BTP
# 1                       ACT Senegal         BTP
# 2          Groupe Atepa Technologie  BTP/MINIER
# 3              Technosol ingénierie         BTP
# 4               OBKmat Construction         BTP
# 5                        Groupe CSE         BTP
# 6                       SIAM Groupe         BTP
# 7                 SADIA Travaux BTP         BTP
# 8                             Batix         BTP
# 9                   UVEN Corporates  BTP/MINIER
#
#                                              address  \
# 0  Km 4,8 Boulevard du Centenaire de la Commune d...
# 1  Avenue Félix Eboué – BP: 21852 Dakar Ponty, Da...
# 2  Bd Martin Luther King-Fann Mermoz – Dakar, Sén...
# 3  Rue 14 prolongée, Lot N°09 Zone Ind. SONEPI, D...
# 4  02 Ouest Foire | Immeuble Adja Kiné, Dakar, Sé...
# 5         Rocade Fann Bel-Air, BP 609 Dakar, Sénégal
# 6           Mamelles BP 24511 Ouakam, Dakar, Sénégal
# 7  Guédiawaye, Cité Gadaye, Lot N1, prolongement ...
# 8           Batix Résidence Rokhaya – Dakar, Sénégal
# 9  Dakar, 30 liberté 6 extension, Rue LIB-35 Daka...
#
#                                 email  \
# 0                      soeco@soeco.sn
# 1                  contact@act-sn.com
# 2                     atepa@atepa.com
# 3  technosol@technosol-ingenierie.com
# 4                  contact@obkmat.com
# 5                 csesn@groupecse.com
# 6             contact@siam-groupe.com
# 7           contact@sadia-travaux.com
# 8                      batix@batix.sn
# 9                contact@uvencorp.com
#
#                                             phones     pays
# 0                                221/ 33 859 90 90  SENEGAL
# 1            +221 33 823 12 77 / +221 33 821 96 96  SENEGAL
# 2  +221/ 865 11 11/ 33 865 11 11 / +221/ 824 90 72  SENEGAL
# 3                                +221 33 825 40 28  SENEGAL
# 4            +221 33 820 00 27 / +221 77 637 66 15  SENEGAL
# 5            +221 33 859 03 00 / +221 33 832 03 95  SENEGAL
# 6                                +221 33 820 54 24  SENEGAL
# 7            +221 33 820 33 94 / +221 77 395 76 51  SENEGAL
# 8         +221 / 33/ 859 55 00 / +221 33 820 47 05  SENEGAL
# 9                                                   SENEGAL

# %%
df.to_csv("companies.csv", index=False)
print(f"\nCompanies saved: {len(df)} companies")
# Out:
# Companies saved: 10 companies
