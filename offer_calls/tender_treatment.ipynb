# %%
import pandas as pd
import re

from camelot.cli import pass_config

# %%
df = pd.read_excel('tenders.xlsx')
print(df.shape)
df.head()
# Out:
# (6693, 10)
#       offer_type                                        description  country  \
# 0  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
# 1  Appel d’offre  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...  Sénégal
# 2  Appel d’offre  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...  Sénégal
# 3  Appel d’offre  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...  Sénégal
# 4  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
#
#   publication_date expiry_date                     secteurs  \
# 0       10/01/2026  15/01/2026  Maintenance et réparations,
# 1       10/01/2026  15/01/2026                    Batiment,
# 2       10/01/2026  10/02/2026    Batiment,Travaux publics,
# 3       10/01/2026  29/01/2026       Automobiles, roulants,
# 4       10/01/2026  15/01/2026             Travaux publics,
#
#                                                 link  \
# 0  https://www.business-senegal.com/fre/Entrepris...
# ...

# %%
df = df[df['country'] == 'Sénégal']
print(df.shape)
df.head()
# Out:
# (5781, 10)
#       offer_type                                        description  country  \
# 0  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
# 1  Appel d’offre  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...  Sénégal
# 2  Appel d’offre  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...  Sénégal
# 3  Appel d’offre  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...  Sénégal
# 4  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
#
#   publication_date expiry_date                     secteurs  \
# 0       10/01/2026  15/01/2026  Maintenance et réparations,
# 1       10/01/2026  15/01/2026                    Batiment,
# 2       10/01/2026  10/02/2026    Batiment,Travaux publics,
# 3       10/01/2026  29/01/2026       Automobiles, roulants,
# 4       10/01/2026  15/01/2026             Travaux publics,
#
#                                                 link  \
# 0  https://www.business-senegal.com/fre/Entrepris...
# ...

# %%
df['offer_type'].unique()
# Out:
# array(['Appel d’offre', 'Appel manifestation / proposition',
#        'Appel à consultation', 'Annonce Business', 'Offre de Services',
#        'Passation de marché', 'Immobilier', 'Demande de Prix'],
#       dtype=object)

# %%
df['phones'].unique()
# Out:
# array(["['2221776449596', '+221 338243334', '+221 ']", "['2']", nan,
#        "['+221 769049463', '2221']",
#        "['+221 773386002', '2221772194262', '+221 772194262']",
#        "['2221770581895', '+221 770581895']",
#        "['+221 338979154', '+221 ', '2221771358616']",
#        "['+221 787771717', '2221787771717']",
#        "['2221786880909', '+221 786880909']",
#        "['+221 782955063', '2221782955063']",
#        "['+221 781363182', '2221781363182']",
#        "['2221786851616', '+221 786851616']",
#        "['2221778984065', '+221 ', '+221 339590942']",
#        "['+221 338565205', '+221 781517676', '2221781517676']",
#        "['+221 338367976', '2221779763820', '+221 ']",
#        "['+221 781894551', '+221 ', '2221']"], dtype=object)

# %%
from func import normalize_number


df['phones_clean'] = df['phones'].astype(str).apply(
    lambda x: ', '.join(normalize_number(n) for n in re.findall(r'\+?\d[\d\s\-()]{6,}\d', x))
)

# %%
df['phones_clean'].unique()
# Out:
# array(['+221776449596, +221338243334', '', '+221769049463',
#        '+221773386002, +221772194262, +221772194262',
#        '+221770581895, +221770581895', '+221338979154, +221771358616',
#        '+221787771717, +221787771717', '+221786880909, +221786880909',
#        '+221782955063, +221782955063', '+221781363182, +221781363182',
#        '+221786851616, +221786851616', '+221778984065, +221339590942',
#        '+221338565205, +221781517676, +221781517676',
#        '+221338367976, +221779763820', '+221781894551'], dtype=object)

# %%
df.drop('web_site', axis=1, inplace=True)
df['address'].unique()
# Out:
# array(['Liberté 6 extension\r\nLiberté 6 extension', nan,
#        'Cité Sotrac, Keur Massar', 'sacré cœur 3',
#        'Liberté 6\r\nliberté 6 extension',
#        'colobane gouye mouride\r\nRufisque', 'Jaxaay 2 - Dakar',
#        'Scat urbam 12522- Dakar',
#        'Touba, usine glace, soumpe baye diagne\r\nDakar, Liberté 6',
#        'TOUBA DIANATOUL MAHWA', 'Lac Rose - Deni Guedj Sud',
#        'SIPRES MBAO RUFISQUE', 'Parcelles Assainies unité 5',
#        'Médina rue 31 x 18', 'Green Globe BTP Ouest foire Dakar, Sénégal'],
#       dtype=object)

# %%
df.head()
# Out:
#       offer_type                                        description  country  \
# 0  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
# 1  Appel d’offre  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...  Sénégal
# 2  Appel d’offre  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...  Sénégal
# 3  Appel d’offre  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...  Sénégal
# 4  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
#
#   publication_date expiry_date                     secteurs  \
# 0       10/01/2026  15/01/2026  Maintenance et réparations,
# 1       10/01/2026  15/01/2026                    Batiment,
# 2       10/01/2026  10/02/2026    Batiment,Travaux publics,
# 3       10/01/2026  29/01/2026       Automobiles, roulants,
# 4       10/01/2026  15/01/2026             Travaux publics,
#
#                                                 link  \
# 0  https://www.business-senegal.com/fre/Entrepris...
# ...

# %%
df['phones'] = df['phones_clean']
df["phones"] = df["phones"].astype(str)
df.drop('phones_clean', axis=1, inplace=True)
df.head()
# Out:
#       offer_type                                        description  country  \
# 0  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
# 1  Appel d’offre  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...  Sénégal
# 2  Appel d’offre  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...  Sénégal
# 3  Appel d’offre  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...  Sénégal
# 4  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
#
#   publication_date expiry_date                     secteurs  \
# 0       10/01/2026  15/01/2026  Maintenance et réparations,
# 1       10/01/2026  15/01/2026                    Batiment,
# 2       10/01/2026  10/02/2026    Batiment,Travaux publics,
# 3       10/01/2026  29/01/2026       Automobiles, roulants,
# 4       10/01/2026  15/01/2026             Travaux publics,
#
#                                                 link  \
# 0  https://www.business-senegal.com/fre/Entrepris...
# ...

# %%
data = []
info = {}

for link in df['link']:
    if link not in data:
        data.append(link)

print(len(data))
# Out:
# 15

# %%
org_info = [
    {
        'organization': 'Dobiza',
        'website': 'http://guindo.co/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/1/annonceur'
    },

    {
        'organization': '',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/0/annonceur'
    },

    {
        'organization': 'Seckanet',
        'website': 'http://www.seckanet.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19292/annonceur'
    },

    {
        'organization': 'Bfast AI',
        'website': 'http://bfast-ai.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19325/annonceur'
    },

    {
        'organization': 'BAYE-EQUIPMENT',
        'website': 'http://bayeconnect.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19149/annonceur'
    },

    {
        'organization': 'FAUCON GROUPE SENEGAL',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/18571/annonceur'
    },

    {
        'organization': 'Africa Technoloogie Plus',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19287/annonceur'
    },

    {
        'organization': 'ACTAS',
        'website': 'http://goactas.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19285/annonceur'
    },

    {
        'organization': 'BATI CHIC',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19227/annonceur'
    },

    {
        'organization': 'SOCIETE COMMERCIALE SOKHNA FADIA MBACKE LO ET FRERES',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/18680/annonceur'
    },

    {
        'organization': 'SEN MATTONI',
        'website': 'http://www.senmattoni.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19248/annonceur'
    },

    {
        'organization': 'SENEGAL TRACTOR',
        'website': 'http://www.senegaltractor.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19039/annonceur'
    },

    {
        'organization': 'Destination Agencie',
        'website': '',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19196/annonceur'
    },

    {
        'organization': 'Amzi Group',
        'website': 'http://www.amzi-group.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19093/annonceur'
    },

    {
        'organization': 'Green Glob BTP',
        'website': 'http://www.greenglobebtp.com/',
        'reference_link': 'https://www.business-senegal.com/fre/Entreprises/profilsample/19010/annonceur'
    },

]

df_info = pd.DataFrame(org_info)
df_final = df.merge(df_info, left_on='link', right_on='reference_link', how='left')
df_final.drop('reference_link', axis=1, inplace=True)
df_final.head()
# Out:
#       offer_type                                        description  country  \
# 0  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
# 1  Appel d’offre  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...  Sénégal
# 2  Appel d’offre  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...  Sénégal
# 3  Appel d’offre  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...  Sénégal
# 4  Appel d’offre  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...  Sénégal
#
#   publication_date expiry_date                     secteurs  \
# 0       10/01/2026  15/01/2026  Maintenance et réparations,
# 1       10/01/2026  15/01/2026                    Batiment,
# 2       10/01/2026  10/02/2026    Batiment,Travaux publics,
# 3       10/01/2026  29/01/2026       Automobiles, roulants,
# 4       10/01/2026  15/01/2026             Travaux publics,
#
#                                                 link  \
# 0  https://www.business-senegal.com/fre/Entrepris...
# ...

# %%
new_order = ['organization', 'description', 'offer_type', 'secteurs', 'address', 'country', 'publication_date', 'expiry_date', 'website', 'link', 'phones']
df_final = df_final[new_order]
df_final.drop('link', inplace=True, axis=1)
print(df.shape)
df_final.head()
# Out:
# (5781, 9)
#   organization                                        description  \
# 0       Dobiza  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...
# 1       Dobiza  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...
# 2       Dobiza  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...
# 3       Dobiza  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...
# 4       Dobiza  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...
#
#       offer_type                     secteurs  \
# 0  Appel d’offre  Maintenance et réparations,
# 1  Appel d’offre                    Batiment,
# 2  Appel d’offre    Batiment,Travaux publics,
# 3  Appel d’offre       Automobiles, roulants,
# 4  Appel d’offre             Travaux publics,
#
#                                       address  country publication_date  \
# 0  Liberté 6 extension\r\nLiberté 6 extension  Sénégal       10/01/2026
# 1  Liberté 6 extension\r\nLiberté 6 extension  Sénégal       10/01/2026
# ...

# %%
df_final.to_csv('clean_tenders.csv', index=False)

# %%
from func import normalize_phones_field
df_final['phones'] = df_final['phones'].apply(normalize_phones_field)
df_final['phones'] = df_final['phones'].astype(str)
# Split by comma into separate columns
df_final[["phone1", "phone2"]] = df_final["phones"].str.split(", ", n=1, expand=True)

# Clean whitespace
df_final["phone1"] = df_final["phone1"].str.strip()
df_final["phone2"] = df_final["phone2"].str.strip()
df_final.head()
df_final.drop_duplicates()
# Out:
#      organization                                        description  \
# 0          Dobiza  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...
# 1          Dobiza  SUPERVISION DES TRAVAUX DE CONSTRUCTION POUR L...
# 2          Dobiza  TRAVAUX DE CONSTRUCTION DU CENTRE DE TRANSFORM...
# 3          Dobiza  ACQUISITION DE VEHICULES POUR LEXPLOITATION DE...
# 4          Dobiza  TRAVAUX DE MAINTENANCE DE PERIMETRES IRRIGUES ...
# ...           ...                                                ...
# 4694       Dobiza  APPEL D’OFFRES : SERIE DE VIDEOS TIKTOK « L’AV...
# 4695       Dobiza  APPEL A CANDIDATURES A ONU FEMMES (23 NOVEMBRE...
# 4696       Dobiza  AVIS D'APPEL D’OFFRES - SERVICE DE MAINTENANCE...
# 5218       Dobiza  FOURNITURE DIVERSES ELECTROPOMPES (CIRCUIT INC...
# 5231       Dobiza  CONSULTANT - CAPITALISATION DE L’ACCOMPAGNEMEN...
#
#                              offer_type  \
# 0                         Appel d’offre
# 1                         Appel d’offre
# ...

# %%
df_final.to_excel('clean_tenders.xlsx', index=False)
df_final.shape
# Out:
# (5781, 12)
